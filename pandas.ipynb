# %%
import pandas as pd

li=[1,2,3,4]
a=pd.Series(li,index=['a','b','c','d'])
a
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
dis={
    "name":["abc","xyz","anku"],
    "salary":[20000,10000,23000]
}
a=pd.Series(dis)
a
# Out:
# name           [abc, xyz, anku]
# salary    [20000, 10000, 23000]
# dtype: object

# %%
s1=pd.Series(12,index=[1,2,3,4,5,6])
s2=pd.Series(12,index=[2,4,5])
print(s1+s2)
# Out:
# 1     NaN
# 2    24.0
# 3     NaN
# 4    24.0
# 5    24.0
# 6     NaN
# dtype: float64

# %%
import pandas as pd
list=[1,2,3,4,5]
var=pd.DataFrame(list)
var
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
dis={
    "name":["abc","xyz","anku"],
    "salary":[20000,10000,50000]
}
ab=pd.DataFrame(dis)
ab
# Out:
#    name  salary
# 0   abc   20000
# 1   xyz   10000
# 2  anku   50000

# %%
li=[[3,4,5,6],[5,6,7,8]]
sb=pd.DataFrame(li)
sb
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  5  6  7  8

# %%
import pandas as pd
var=pd.DataFrame({
    "a":[2,4,5],
    "b":[6,8,9]
})
var["c"]=var["a"]*var["b"]
var["c"]
# Out:
# 0    12
# 1    32
# 2    45
# Name: c, dtype: int64
